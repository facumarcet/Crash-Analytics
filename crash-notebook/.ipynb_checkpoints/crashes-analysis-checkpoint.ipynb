# %%
import requests
from pprint import pprint
dbServiceUrl = 'http://192.168.0.14:8080'
req = requests.get(dbServiceUrl+'/rocketCrash/getAll')
pprint(req.json())
# Out:
# [{'crashPoint': 4.12, 'id': '32a6e92a-9a24-40ed-aefc-eafadc33a5ce'},
#  {'crashPoint': 1.24, 'id': '94f4490f-310b-4b8c-bfd8-095d36f43e56'},
#  {'crashPoint': 2.18, 'id': '65f6fc7b-27cc-4ed4-81f0-fac33ffa2d3e'},
#  {'crashPoint': 3.57, 'id': 'ece6ae97-9830-450c-9fc7-1e90b47ba20f'},
#  {'crashPoint': 1.0, 'id': '89b5d1fc-e408-4ebc-88e7-17f90d8fec3a'},
#  {'crashPoint': 9.11, 'id': '44abb7f9-5683-428f-a008-facfae468114'},
#  {'crashPoint': 8.36, 'id': 'a74d25de-1882-48bc-8029-ec7200cbc395'},
#  {'crashPoint': 3.1, 'id': '9c92396d-f26d-4a54-95da-458ef8d22f2f'},
#  {'crashPoint': 1.36, 'id': '1df805bd-bd55-4c37-ad41-e69327e51fed'},
#  {'crashPoint': 2.39, 'id': '9ecece06-9067-4e39-97fb-1d4a599ea933'},
#  {'crashPoint': 1.0, 'id': 'fbe7283b-d389-4de9-b5d8-cc1cd8014d99'},
#  {'crashPoint': 2.7, 'id': '108355b8-4216-48c7-b736-04bab6e995bb'},
#  {'crashPoint': 1.82, 'id': '03c4c2d2-4c37-4d0f-ba55-5ff63121d193'},
#  {'crashPoint': 1.1, 'id': 'dc9d4fe5-1a10-45e0-ba4d-cb6c3987e77d'},
# ...
